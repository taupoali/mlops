# %% [markdown]
# # Overview
#
# SageMaker Inference Recommender is a new capability of SageMaker that reduces the time required to get machine learning (ML) models in production by automating performance benchmarking and load testing models across SageMaker ML instances. You can use Inference Recommender to deploy your model to a real-time inference endpoint that delivers the best performance at the lowest cost.

# %% [markdown]
# Inference recommender

# %%
# %%capture
! pip install --upgrade sagemaker

# %% [markdown]
# # Model training and evaluation

# %% [markdown]
# ### Data exploration
# refer to the link below for additional information about the data set
# [Regression with Amazon SageMaker Linear Learner algorithm](https://sagemaker-examples.readthedocs.io/en/latest/introduction_to_amazon_algorithms/linear_learner_abalone/Linear_Learner_Regression_csv_format.html#Regression-with-Amazon-SageMaker-Linear-Learner-algorithm)

# %%
import os
import boto3
import re
import sagemaker
import time
import numpy as np
import pandas as pd
from datetime import datetime, timedelta


role = sagemaker.get_execution_role()
region = boto3.Session().region_name
sm_client = boto3.client('sagemaker', region_name=region)

# S3 bucket for training data.
# Feel free to specify a different bucket and prefix.
data_bucket = f"sagemaker-example-files-prod-{region}"
data_prefix = "datasets/tabular/uci_abalone"


# S3 bucket for saving code and model artifacts.
# Feel free to specify a different bucket and prefix
output_bucket = sagemaker.Session().default_bucket()
output_prefix = "sagemaker/DEMO-linear-learner-abalone-regression"
xgb_output_prefix = "sagemaker/DEMO-xgb-abalone-regression"
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml

# %%
s3 = boto3.client("s3")

FILE_TRAIN = "abalone_dataset1_train.csv"
FILE_TEST = "abalone_dataset1_test.csv"
FILE_VALIDATION = "abalone_dataset1_validation.csv"

# downloading the train, test, and validation files from data_bucket
s3.download_file(data_bucket, f"{data_prefix}/train_csv/{FILE_TRAIN}", FILE_TRAIN)
s3.download_file(data_bucket, f"{data_prefix}/test_csv/{FILE_TEST}", FILE_TEST)
s3.download_file(data_bucket, f"{data_prefix}/validation_csv/{FILE_VALIDATION}", FILE_VALIDATION)
s3.upload_file(FILE_TRAIN, output_bucket, f"{output_prefix}/train/{FILE_TRAIN}")
s3.upload_file(FILE_TEST, output_bucket, f"{output_prefix}/test/{FILE_TEST}")
s3.upload_file(FILE_VALIDATION, output_bucket, f"{output_prefix}/validation/{FILE_VALIDATION}")

# %%
df = pd.read_csv(
    FILE_TRAIN,
    sep=",",
    encoding="latin1",
    names=[
        "age",
        "sex",
        "Length",
        "Diameter",
        "Height",
        "Whole.weight",
        "Shucked.weight",
        "Viscera.weight",
        "Shell.weight",
    ],
)
print(df.head(1))
# Out:
#    age  sex  Length  Diameter  Height  Whole.weight  Shucked.weight  \
# 0    8    2   0.615      0.48    0.16        1.2525           0.585
#
#    Viscera.weight  Shell.weight
# 0          0.2595          0.33

# %% [markdown]
# ### Configure train and validation channel

# %%
# creating the inputs for the fit() function with the training and validation location
s3_train_data = f"s3://{output_bucket}/{output_prefix}/train"
print(f"training files will be taken from: {s3_train_data}")
s3_validation_data = f"s3://{output_bucket}/{output_prefix}/validation"
print(f"validation files will be taken from: {s3_validation_data}")
output_location = f"s3://{output_bucket}/{output_prefix}/output"
print(f"training artifacts output location: {output_location}")

# generating the session.s3_input() format for fit() accepted by the sdk
train_data = sagemaker.inputs.TrainingInput(
    s3_train_data,
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
    record_wrapping=None,
    compression=None,
)
validation_data = sagemaker.inputs.TrainingInput(
    s3_validation_data,
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
    record_wrapping=None,
    compression=None,
)
# Out:
# training files will be taken from: s3://sagemaker-us-east-1-220653215381/sagemaker/DEMO-linear-learner-abalone-regression/train
# validation files will be taken from: s3://sagemaker-us-east-1-220653215381/sagemaker/DEMO-linear-learner-abalone-regression/validation
# training artifacts output location: s3://sagemaker-us-east-1-220653215381/sagemaker/DEMO-linear-learner-abalone-regression/output

# %% [markdown]
# ### Configure the linear estimator

# %%
# getting the linear learner image according to the region
from sagemaker.image_uris import retrieve

container = retrieve("linear-learner", boto3.Session().region_name, version="1")
print(container)
deploy_amt_model = False
# Out:
# 382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1

# %%
# %%time
import boto3
import sagemaker
from time import gmtime, strftime

sess = sagemaker.Session()

job_name = "DEMO-linear-learner-abalone-regression-" + strftime("%Y%m%d-%H-%M-%S", gmtime())
print("Training job", job_name)

linear = sagemaker.estimator.Estimator(
    container,
    role,
    input_mode="File",
    instance_count=1,
    instance_type="ml.m4.xlarge",
    output_path=output_location,
    sagemaker_session=sess,
)

linear.set_hyperparameters(
    feature_dim=8,
    epochs=16,
    wd=0.01,
    loss="absolute_loss",
    predictor_type="regressor",
    normalize_data=True,
    optimizer="adam",
    mini_batch_size=100,
    lr_scheduler_step=100,
    lr_scheduler_factor=0.99,
    lr_scheduler_minimum_lr=0.0001,
    learning_rate=0.1,
)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml
# Training job DEMO-linear-learner-abalone-regression-20231116-03-40-51
# CPU times: user 33.1 ms, sys: 3.45 ms, total: 36.6 ms
# Wall time: 36.4 ms

# %% [markdown]
# ### Train the linear model

# %%
# %%time
linear.fit(inputs={"train": train_data, "validation": validation_data}, job_name=job_name)
# Out:
# INFO:sagemaker:Creating training-job with name: DEMO-linear-learner-abalone-regression-20231116-03-40-51
# 2023-11-16 03:41:06 Starting - Starting the training job...
# 2023-11-16 03:41:30 Starting - Preparing the instances for training.........
# 2023-11-16 03:42:47 Downloading - Downloading input data...
# 2023-11-16 03:43:30 Training - Downloading the training image......
# 2023-11-16 03:44:31 Training - Training image download completed. Training in progress....Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [11/16/2023 03:44:50 INFO 140126792275776] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [11/16/2023 03:44:50 INFO 140126792275776] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'epochs': '16', 'feature_dim': '8', 'learning_rate': '0.1', 'loss': 'absolute_loss', 'lr_scheduler_factor': '0.99', 'lr_scheduler_minimum_lr': '0.0001', 'lr_scheduler_step': '100', 'mini_batch_size': '100', 'normalize_data': 'True', 'optimizer': 'adam', 'predictor_type': 'regressor', 'wd': '0.01'}
# [11/16/2023 03:44:50 INFO 140126792275776] Final configuration: {'mini_batch_size': '100', 'epochs': '16', 'feature_dim': '8', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'adam', 'loss': 'absolute_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': '0.01', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': '0.1', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': '100', 'lr_scheduler_factor': '0.99', 'lr_scheduler_minimum_lr': '0.0001', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'True', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [11/16/2023 03:44:53 WARNING 140126792275776] Loggers have already been setup.
# [11/16/2023 03:44:53 INFO 140126792275776] Final configuration: {'mini_batch_size': '100', 'epochs': '16', 'feature_dim': '8', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'adam', 'loss': 'absolute_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': '0.01', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': '0.1', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': '100', 'lr_scheduler_factor': '0.99', 'lr_scheduler_minimum_lr': '0.0001', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'True', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [11/16/2023 03:44:53 WARNING 140126792275776] Loggers have already been setup.
# Process 7 is a worker.
# [11/16/2023 03:44:53 INFO 140126792275776] Using default worker.
# [11/16/2023 03:44:53 INFO 140126792275776] Checkpoint loading and saving are disabled.
# [11/16/2023 03:44:53 INFO 140126792275776] Create Store: local
# [11/16/2023 03:44:54 INFO 140126792275776] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f713fb53ee0>
# [11/16/2023 03:44:54 INFO 140126792275776] Scaling model computed with parameters:
#  {'stdev_label':
# [3.166506]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [0.82859373 0.11902981 0.09828231 0.04304462 0.49319965 0.22228865
#  0.10972665 0.1398607 ]
# <NDArray 8 @cpu(0)>, 'mean_label':
# [9.946205]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [1.9510345  0.5242224  0.40774652 0.13964482 0.82909757 0.3594457
#  0.18022536 0.23893827]
# <NDArray 8 @cpu(0)>}
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [11/16/2023 03:44:54 INFO 140126792275776] nvidia-smi: took 0.034 seconds to run.
# [11/16/2023 03:44:54 INFO 140126792275776] nvidia-smi identified 0 GPUs.
# [11/16/2023 03:44:54 INFO 140126792275776] Number of GPUs being used: 0
# #metrics {"StartTime": 1700106294.1825216, "EndTime": 1700106294.1825602, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3023.0, "count": 1, "min": 3023, "max": 3023}, "Total Batches Seen": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Max Records Seen Between Resets": {"sum": 2923.0, "count": 1, "min": 2923, "max": 2923}, "Max Batches Seen Between Resets": {"sum": 30.0, "count": 1, "min": 30, "max": 30}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# #metrics {"StartTime": 1700106294.9370787, "EndTime": 1700106294.9371393, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6094744004874394, "count": 1, "min": 0.6094744004874394, "max": 0.6094744004874394}}}
# #metrics {"StartTime": 1700106294.937228, "EndTime": 1700106294.9372487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6159038346389244, "count": 1, "min": 0.6159038346389244, "max": 0.6159038346389244}}}
# #metrics {"StartTime": 1700106294.9373133, "EndTime": 1700106294.937333, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6056723456547178, "count": 1, "min": 0.6056723456547178, "max": 0.6056723456547178}}}
# #metrics {"StartTime": 1700106294.937394, "EndTime": 1700106294.937411, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5942896783762964, "count": 1, "min": 0.5942896783762964, "max": 0.5942896783762964}}}
# #metrics {"StartTime": 1700106294.9374669, "EndTime": 1700106294.9374845, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6194780178727775, "count": 1, "min": 0.6194780178727775, "max": 0.6194780178727775}}}
# #metrics {"StartTime": 1700106294.9375355, "EndTime": 1700106294.937553, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6166930915569437, "count": 1, "min": 0.6166930915569437, "max": 0.6166930915569437}}}
# #metrics {"StartTime": 1700106294.9376082, "EndTime": 1700106294.9376261, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6483573703108163, "count": 1, "min": 0.6483573703108163, "max": 0.6483573703108163}}}
# #metrics {"StartTime": 1700106294.9376814, "EndTime": 1700106294.9376984, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.616730157260237, "count": 1, "min": 0.616730157260237, "max": 0.616730157260237}}}
# #metrics {"StartTime": 1700106294.937749, "EndTime": 1700106294.9377654, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5938256730704472, "count": 1, "min": 0.5938256730704472, "max": 0.5938256730704472}}}
# #metrics {"StartTime": 1700106294.9378145, "EndTime": 1700106294.9378312, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6055349718291184, "count": 1, "min": 0.6055349718291184, "max": 0.6055349718291184}}}
# #metrics {"StartTime": 1700106294.93789, "EndTime": 1700106294.9379067, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6070010283897663, "count": 1, "min": 0.6070010283897663, "max": 0.6070010283897663}}}
# #metrics {"StartTime": 1700106294.937962, "EndTime": 1700106294.9379797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6125913291141905, "count": 1, "min": 0.6125913291141905, "max": 0.6125913291141905}}}
# #metrics {"StartTime": 1700106294.9380352, "EndTime": 1700106294.9380531, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6510009463080044, "count": 1, "min": 0.6510009463080044, "max": 0.6510009463080044}}}
# #metrics {"StartTime": 1700106294.9381146, "EndTime": 1700106294.9381309, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6143604015481883, "count": 1, "min": 0.6143604015481883, "max": 0.6143604015481883}}}
# #metrics {"StartTime": 1700106294.9382207, "EndTime": 1700106294.9382389, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6230542505198512, "count": 1, "min": 0.6230542505198512, "max": 0.6230542505198512}}}
# #metrics {"StartTime": 1700106294.938297, "EndTime": 1700106294.9383147, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.614551930920831, "count": 1, "min": 0.614551930920831, "max": 0.614551930920831}}}
# #metrics {"StartTime": 1700106294.9383743, "EndTime": 1700106294.938392, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6132369416335534, "count": 1, "min": 0.6132369416335534, "max": 0.6132369416335534}}}
# #metrics {"StartTime": 1700106294.9384463, "EndTime": 1700106294.9384644, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6507199478149414, "count": 1, "min": 0.6507199478149414, "max": 0.6507199478149414}}}
# #metrics {"StartTime": 1700106294.9385147, "EndTime": 1700106294.9385312, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5945493592887089, "count": 1, "min": 0.5945493592887089, "max": 0.5945493592887089}}}
# #metrics {"StartTime": 1700106294.938579, "EndTime": 1700106294.938597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.580776832843649, "count": 1, "min": 0.580776832843649, "max": 0.580776832843649}}}
# #metrics {"StartTime": 1700106294.9386473, "EndTime": 1700106294.9386635, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6401544215761382, "count": 1, "min": 0.6401544215761382, "max": 0.6401544215761382}}}
# #metrics {"StartTime": 1700106294.938713, "EndTime": 1700106294.9387298, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6560759064246868, "count": 1, "min": 0.6560759064246868, "max": 0.6560759064246868}}}
# #metrics {"StartTime": 1700106294.938783, "EndTime": 1700106294.9388006, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6552159105498215, "count": 1, "min": 0.6552159105498215, "max": 0.6552159105498215}}}
# #metrics {"StartTime": 1700106294.9388556, "EndTime": 1700106294.9388723, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6286057597193224, "count": 1, "min": 0.6286057597193224, "max": 0.6286057597193224}}}
# #metrics {"StartTime": 1700106294.9389365, "EndTime": 1700106294.9389563, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7228669830848431, "count": 1, "min": 0.7228669830848431, "max": 0.7228669830848431}}}
# #metrics {"StartTime": 1700106294.9390223, "EndTime": 1700106294.9390404, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7112582555310479, "count": 1, "min": 0.7112582555310479, "max": 0.7112582555310479}}}
# #metrics {"StartTime": 1700106294.9390988, "EndTime": 1700106294.9391136, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7441288152234308, "count": 1, "min": 0.7441288152234308, "max": 0.7441288152234308}}}
# #metrics {"StartTime": 1700106294.939149, "EndTime": 1700106294.9391634, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7191895123185783, "count": 1, "min": 0.7191895123185783, "max": 0.7191895123185783}}}
# #metrics {"StartTime": 1700106294.9392235, "EndTime": 1700106294.9392414, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7838475483861462, "count": 1, "min": 0.7838475483861462, "max": 0.7838475483861462}}}
# #metrics {"StartTime": 1700106294.939305, "EndTime": 1700106294.9393234, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.800184395888756, "count": 1, "min": 0.800184395888756, "max": 0.800184395888756}}}
# #metrics {"StartTime": 1700106294.9393835, "EndTime": 1700106294.9394004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7845329837141366, "count": 1, "min": 0.7845329837141366, "max": 0.7845329837141366}}}
# #metrics {"StartTime": 1700106294.93946, "EndTime": 1700106294.939477, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7828742033859779, "count": 1, "min": 0.7828742033859779, "max": 0.7828742033859779}}}
# [11/16/2023 03:44:54 INFO 140126792275776] #quality_metric: host=algo-1, epoch=0, train absolute_loss_objective <loss>=0.6094744004874394
# #metrics {"StartTime": 1700106295.0558174, "EndTime": 1700106295.055872, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.614692736738406, "count": 1, "min": 1.614692736738406, "max": 1.614692736738406}}}
# #metrics {"StartTime": 1700106295.0559578, "EndTime": 1700106295.055972, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8428490733186278, "count": 1, "min": 1.8428490733186278, "max": 1.8428490733186278}}}
# #metrics {"StartTime": 1700106295.0560367, "EndTime": 1700106295.0560546, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8338534260710206, "count": 1, "min": 1.8338534260710206, "max": 1.8338534260710206}}}
# #metrics {"StartTime": 1700106295.0561192, "EndTime": 1700106295.0561373, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8322077315455427, "count": 1, "min": 1.8322077315455427, "max": 1.8322077315455427}}}
# #metrics {"StartTime": 1700106295.056193, "EndTime": 1700106295.056208, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6331035930889484, "count": 1, "min": 1.6331035930889484, "max": 1.6331035930889484}}}
# #metrics {"StartTime": 1700106295.0562632, "EndTime": 1700106295.0562804, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.625213793672312, "count": 1, "min": 1.625213793672312, "max": 1.625213793672312}}}
# #metrics {"StartTime": 1700106295.0563362, "EndTime": 1700106295.056352, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.676778409427728, "count": 1, "min": 1.676778409427728, "max": 1.676778409427728}}}
# #metrics {"StartTime": 1700106295.0564122, "EndTime": 1700106295.056424, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.7225111391597663, "count": 1, "min": 1.7225111391597663, "max": 1.7225111391597663}}}
# #metrics {"StartTime": 1700106295.0564606, "EndTime": 1700106295.056473, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8316844050495769, "count": 1, "min": 1.8316844050495769, "max": 1.8316844050495769}}}
# #metrics {"StartTime": 1700106295.056525, "EndTime": 1700106295.0565429, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.836703760555377, "count": 1, "min": 1.836703760555377, "max": 1.836703760555377}}}
# #metrics {"StartTime": 1700106295.0565984, "EndTime": 1700106295.0566163, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8480722713775146, "count": 1, "min": 1.8480722713775146, "max": 1.8480722713775146}}}
# #metrics {"StartTime": 1700106295.0566733, "EndTime": 1700106295.0566845, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8872812655025397, "count": 1, "min": 1.8872812655025397, "max": 1.8872812655025397}}}
# #metrics {"StartTime": 1700106295.0567288, "EndTime": 1700106295.0567434, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6487221946350683, "count": 1, "min": 1.6487221946350683, "max": 1.6487221946350683}}}
# #metrics {"StartTime": 1700106295.0567927, "EndTime": 1700106295.0568082, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6542381615684436, "count": 1, "min": 1.6542381615684436, "max": 1.6542381615684436}}}
# #metrics {"StartTime": 1700106295.0568624, "EndTime": 1700106295.0568793, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6736299923052802, "count": 1, "min": 1.6736299923052802, "max": 1.6736299923052802}}}
# #metrics {"StartTime": 1700106295.0569336, "EndTime": 1700106295.0569499, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6074060312094398, "count": 1, "min": 1.6074060312094398, "max": 1.6074060312094398}}}
# #metrics {"StartTime": 1700106295.0570123, "EndTime": 1700106295.0570285, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.820774559776623, "count": 1, "min": 1.820774559776623, "max": 1.820774559776623}}}
# #metrics {"StartTime": 1700106295.0570834, "EndTime": 1700106295.0571003, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8396683348634373, "count": 1, "min": 1.8396683348634373, "max": 1.8396683348634373}}}
# #metrics {"StartTime": 1700106295.057156, "EndTime": 1700106295.0571725, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.844088557429207, "count": 1, "min": 1.844088557429207, "max": 1.844088557429207}}}
# #metrics {"StartTime": 1700106295.0572367, "EndTime": 1700106295.0572538, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.7965731087584085, "count": 1, "min": 1.7965731087584085, "max": 1.7965731087584085}}}
# #metrics {"StartTime": 1700106295.0573163, "EndTime": 1700106295.0573354, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8257613989491812, "count": 1, "min": 1.8257613989491812, "max": 1.8257613989491812}}}
# #metrics {"StartTime": 1700106295.057392, "EndTime": 1700106295.0574095, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.7961077400670646, "count": 1, "min": 1.7961077400670646, "max": 1.7961077400670646}}}
# #metrics {"StartTime": 1700106295.0574656, "EndTime": 1700106295.0574825, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8590215067513072, "count": 1, "min": 1.8590215067513072, "max": 1.8590215067513072}}}
# #metrics {"StartTime": 1700106295.0575383, "EndTime": 1700106295.057556, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8733244825856754, "count": 1, "min": 1.8733244825856754, "max": 1.8733244825856754}}}
# #metrics {"StartTime": 1700106295.0576084, "EndTime": 1700106295.0576248, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.34163768756123, "count": 1, "min": 2.34163768756123, "max": 2.34163768756123}}}
# #metrics {"StartTime": 1700106295.0576792, "EndTime": 1700106295.0576973, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.3840188584007773, "count": 1, "min": 2.3840188584007773, "max": 2.3840188584007773}}}
# #metrics {"StartTime": 1700106295.057752, "EndTime": 1700106295.0577683, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.299903065251847, "count": 1, "min": 2.299903065251847, "max": 2.299903065251847}}}
# #metrics {"StartTime": 1700106295.0578227, "EndTime": 1700106295.0578394, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.36035958189553, "count": 1, "min": 2.36035958189553, "max": 2.36035958189553}}}
# #metrics {"StartTime": 1700106295.0578942, "EndTime": 1700106295.0579116, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.416993954692024, "count": 1, "min": 2.416993954692024, "max": 2.416993954692024}}}
# #metrics {"StartTime": 1700106295.0579712, "EndTime": 1700106295.057988, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.6578622153772713, "count": 1, "min": 2.6578622153772713, "max": 2.6578622153772713}}}
# #metrics {"StartTime": 1700106295.058044, "EndTime": 1700106295.058061, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.41207616397748, "count": 1, "min": 2.41207616397748, "max": 2.41207616397748}}}
# #metrics {"StartTime": 1700106295.05811, "EndTime": 1700106295.058126, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.342342059833173, "count": 1, "min": 2.342342059833173, "max": 2.342342059833173}}}
# [11/16/2023 03:44:55 INFO 140126792275776] #quality_metric: host=algo-1, epoch=0, validation absolute_loss_objective <loss>=1.614692736738406
# [11/16/2023 03:44:55 INFO 140126792275776] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=absolute_loss_objective, value=1.6074060312094398
# [11/16/2023 03:44:55 INFO 140126792275776] Epoch 0: Loss improved. Updating best model
# [11/16/2023 03:44:55 INFO 140126792275776] Saving model for epoch: 0
# [11/16/2023 03:44:55 INFO 140126792275776] Saved checkpoint to "/tmp/tmpd7vd_oe_/mx-mod-0000.params"
# [11/16/2023 03:44:55 INFO 140126792275776] #progress_metric: host=algo-1, completed 6.25 % of epochs
# #metrics {"StartTime": 1700106294.182849, "EndTime": 1700106295.0658906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 5946.0, "count": 1, "min": 5946, "max": 5946}, "Total Batches Seen": {"sum": 61.0, "count": 1, "min": 61, "max": 61}, "Max Records Seen Between Resets": {"sum": 2923.0, "count": 1, "min": 2923, "max": 2923}, "Max Batches Seen Between Resets": {"sum": 30.0, "count": 1, "min": 30, "max": 30}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 2923.0, "count": 1, "min": 2923, "max": 2923}, "Number of Batches Since Last Reset": {"sum": 30.0, "count": 1, "min": 30, "max": 30}}}
# [11/16/2023 03:44:55 INFO 140126792275776] #throughput_metric: host=algo-1, train throughput=3309.638616781447 records/second
# #metrics {"StartTime": 1700106295.8076792, "EndTime": 1700106295.8077385, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5217510828478583, "count": 1, "min": 0.5217510828478583, "max": 0.5217510828478583}}}
# #metrics {"StartTime": 1700106295.807824, "EndTime": 1700106295.8078384, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5527208538713126, "count": 1, "min": 0.5527208538713126, "max": 0.5527208538713126}}}
# #metrics {"StartTime": 1700106295.8079069, "EndTime": 1700106295.807927, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5481303024291992, "count": 1, "min": 0.5481303024291992, "max": 0.5481303024291992}}}
# #metrics {"StartTime": 1700106295.8079803, "EndTime": 1700106295.8079977, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5539223848540208, "count": 1, "min": 0.5539223848540208, "max": 0.5539223848540208}}}
# #metrics {"StartTime": 1700106295.808059, "EndTime": 1700106295.808077, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5270506247158708, "count": 1, "min": 0.5270506247158708, "max": 0.5270506247158708}}}
# #metrics {"StartTime": 1700106295.8081293, "EndTime": 1700106295.808146, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5284165625736631, "count": 1, "min": 0.5284165625736631, "max": 0.5284165625736631}}}
# #metrics {"StartTime": 1700106295.808196, "EndTime": 1700106295.8082125, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5305748472542599, "count": 1, "min": 0.5305748472542599, "max": 0.5305748472542599}}}
# #metrics {"StartTime": 1700106295.8082771, "EndTime": 1700106295.8082957, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5165529474718817, "count": 1, "min": 0.5165529474718817, "max": 0.5165529474718817}}}
# #metrics {"StartTime": 1700106295.8083522, "EndTime": 1700106295.8083699, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5526098027722589, "count": 1, "min": 0.5526098027722589, "max": 0.5526098027722589}}}
# #metrics {"StartTime": 1700106295.808422, "EndTime": 1700106295.8084385, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5514624168132913, "count": 1, "min": 0.5514624168132913, "max": 0.5514624168132913}}}
# #metrics {"StartTime": 1700106295.808506, "EndTime": 1700106295.808524, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5583857884900323, "count": 1, "min": 0.5583857884900323, "max": 0.5583857884900323}}}
# #metrics {"StartTime": 1700106295.8085902, "EndTime": 1700106295.8086073, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5621750930259968, "count": 1, "min": 0.5621750930259968, "max": 0.5621750930259968}}}
# #metrics {"StartTime": 1700106295.8086636, "EndTime": 1700106295.8086815, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.522969259064773, "count": 1, "min": 0.522969259064773, "max": 0.522969259064773}}}
# #metrics {"StartTime": 1700106295.808746, "EndTime": 1700106295.808765, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5216276024127828, "count": 1, "min": 0.5216276024127828, "max": 0.5216276024127828}}}
# #metrics {"StartTime": 1700106295.8088236, "EndTime": 1700106295.8088412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5289100410198343, "count": 1, "min": 0.5289100410198343, "max": 0.5289100410198343}}}
# #metrics {"StartTime": 1700106295.8088949, "EndTime": 1700106295.8089123, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5279291468653186, "count": 1, "min": 0.5279291468653186, "max": 0.5279291468653186}}}
# #metrics {"StartTime": 1700106295.8089821, "EndTime": 1700106295.8090012, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5561696651064116, "count": 1, "min": 0.5561696651064116, "max": 0.5561696651064116}}}
# #metrics {"StartTime": 1700106295.8090613, "EndTime": 1700106295.8090794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5615032025041251, "count": 1, "min": 0.5615032025041251, "max": 0.5615032025041251}}}
# #metrics {"StartTime": 1700106295.8091395, "EndTime": 1700106295.8091567, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5588834538953058, "count": 1, "min": 0.5588834538953058, "max": 0.5588834538953058}}}
# #metrics {"StartTime": 1700106295.809216, "EndTime": 1700106295.809231, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5510331239371464, "count": 1, "min": 0.5510331239371464, "max": 0.5510331239371464}}}
# #metrics {"StartTime": 1700106295.8092618, "EndTime": 1700106295.8092704, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5660990616370891, "count": 1, "min": 0.5660990616370891, "max": 0.5660990616370891}}}
# #metrics {"StartTime": 1700106295.8093016, "EndTime": 1700106295.8093157, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5792966303332099, "count": 1, "min": 0.5792966303332099, "max": 0.5792966303332099}}}
# #metrics {"StartTime": 1700106295.809372, "EndTime": 1700106295.8093889, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5769504823355839, "count": 1, "min": 0.5769504823355839, "max": 0.5769504823355839}}}
# #metrics {"StartTime": 1700106295.8094463, "EndTime": 1700106295.8094642, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5589075851440429, "count": 1, "min": 0.5589075851440429, "max": 0.5589075851440429}}}
# #metrics {"StartTime": 1700106295.8095183, "EndTime": 1700106295.8095353, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7129743418200263, "count": 1, "min": 0.7129743418200263, "max": 0.7129743418200263}}}
# #metrics {"StartTime": 1700106295.8096058, "EndTime": 1700106295.8096256, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7150211676235857, "count": 1, "min": 0.7150211676235857, "max": 0.7150211676235857}}}
# #metrics {"StartTime": 1700106295.8096845, "EndTime": 1700106295.8097026, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.713478678999276, "count": 1, "min": 0.713478678999276, "max": 0.713478678999276}}}
# #metrics {"StartTime": 1700106295.8097603, "EndTime": 1700106295.8097746, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7163546845008587, "count": 1, "min": 0.7163546845008587, "max": 0.7163546845008587}}}
# #metrics {"StartTime": 1700106295.8098254, "EndTime": 1700106295.809844, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7152935264850485, "count": 1, "min": 0.7152935264850485, "max": 0.7152935264850485}}}
# #metrics {"StartTime": 1700106295.8099017, "EndTime": 1700106295.809918, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7218850050301387, "count": 1, "min": 0.7218850050301387, "max": 0.7218850050301387}}}
# #metrics {"StartTime": 1700106295.809963, "EndTime": 1700106295.8099809, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7164106434789197, "count": 1, "min": 0.7164106434789197, "max": 0.7164106434789197}}}
# #metrics {"StartTime": 1700106295.810035, "EndTime": 1700106295.8100526, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.716807386464086, "count": 1, "min": 0.716807386464086, "max": 0.716807386464086}}}
# [11/16/2023 03:44:55 INFO 140126792275776] #quality_metric: host=algo-1, epoch=1, train absolute_loss_objective <loss>=0.5217510828478583
# #metrics {"StartTime": 1700106295.9373195, "EndTime": 1700106295.9373727, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6141948090574612, "count": 1, "min": 1.6141948090574612, "max": 1.6141948090574612}}}
# #metrics {"StartTime": 1700106295.937457, "EndTime": 1700106295.937477, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.7929019501414925, "count": 1, "min": 1.7929019501414925, "max": 1.7929019501414925}}}
# #metrics {"StartTime": 1700106295.9375336, "EndTime": 1700106295.9375522, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.7789544541234026, "count": 1, "min": 1.7789544541234026, "max": 1.7789544541234026}}}
# #metrics {"StartTime": 1700106295.937609, "EndTime": 1700106295.9376256, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.7791217584579517, "count": 1, "min": 1.7791217584579517, "max": 1.7791217584579517}}}
# #metrics {"StartTime": 1700106295.9376822, "EndTime": 1700106295.9377, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6250767936340917, "count": 1, "min": 1.6250767936340917, "max": 1.6250767936340917}}}
# #metrics {"StartTime": 1700106295.9377558, "EndTime": 1700106295.9377728, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6518677050313249, "count": 1, "min": 1.6518677050313249, "max": 1.6518677050313249}}}
# #metrics {"StartTime": 1700106295.9378235, "EndTime": 1700106295.937838, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6578934520197373, "count": 1, "min": 1.6578934520197373, "max": 1.6578934520197373}}}
# #metrics {"StartTime": 1700106295.9379056, "EndTime": 1700106295.9379227, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6213350387426992, "count": 1, "min": 1.6213350387426992, "max": 1.6213350387426992}}}
# #metrics {"StartTime": 1700106295.9379902, "EndTime": 1700106295.9380085, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.7855696205894787, "count": 1, "min": 1.7855696205894787, "max": 1.7855696205894787}}}
# #metrics {"StartTime": 1700106295.938068, "EndTime": 1700106295.938087, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.783131974192854, "count": 1, "min": 1.783131974192854, "max": 1.783131974192854}}}
# #metrics {"StartTime": 1700106295.938143, "EndTime": 1700106295.9381876, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8006340429043999, "count": 1, "min": 1.8006340429043999, "max": 1.8006340429043999}}}
# #metrics {"StartTime": 1700106295.9382594, "EndTime": 1700106295.938278, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8081047253105968, "count": 1, "min": 1.8081047253105968, "max": 1.8081047253105968}}}
# #metrics {"StartTime": 1700106295.93834, "EndTime": 1700106295.9383585, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6440834861974747, "count": 1, "min": 1.6440834861974747, "max": 1.6440834861974747}}}
# #metrics {"StartTime": 1700106295.938411, "EndTime": 1700106295.9384274, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6104153032881765, "count": 1, "min": 1.6104153032881765, "max": 1.6104153032881765}}}
# #metrics {"StartTime": 1700106295.9384987, "EndTime": 1700106295.9385176, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6415193393207586, "count": 1, "min": 1.6415193393207586, "max": 1.6415193393207586}}}
# #metrics {"StartTime": 1700106295.9385853, "EndTime": 1700106295.938604, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.653416039463811, "count": 1, "min": 1.653416039463811, "max": 1.653416039463811}}}
# #metrics {"StartTime": 1700106295.9386709, "EndTime": 1700106295.938691, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.829858773813461, "count": 1, "min": 1.829858773813461, "max": 1.829858773813461}}}
# #metrics {"StartTime": 1700106295.9387472, "EndTime": 1700106295.938764, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8471833981644994, "count": 1, "min": 1.8471833981644994, "max": 1.8471833981644994}}}
# #metrics {"StartTime": 1700106295.938816, "EndTime": 1700106295.938833, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.810401782441063, "count": 1, "min": 1.810401782441063, "max": 1.810401782441063}}}
# #metrics {"StartTime": 1700106295.938875, "EndTime": 1700106295.9388845, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.807433594530002, "count": 1, "min": 1.807433594530002, "max": 1.807433594530002}}}
# ...
# [11/16/2023 03:45:06 INFO 140126792275776] #quality_metric: host=algo-1, epoch=12, train absolute_loss_objective <loss>=0.4958538897284146
# #metrics {"StartTime": 1700106306.5667071, "EndTime": 1700106306.5667648, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 0}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6439013130748614, "count": 1, "min": 1.6439013130748614, "max": 1.6439013130748614}}}
# #metrics {"StartTime": 1700106306.5668654, "EndTime": 1700106306.5668883, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 1}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.635945755833635, "count": 1, "min": 1.635945755833635, "max": 1.635945755833635}}}
# #metrics {"StartTime": 1700106306.5669584, "EndTime": 1700106306.5669782, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 2}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.63483976175229, "count": 1, "min": 1.63483976175229, "max": 1.63483976175229}}}
# #metrics {"StartTime": 1700106306.5670333, "EndTime": 1700106306.5670495, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 3}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6257359075089233, "count": 1, "min": 1.6257359075089233, "max": 1.6257359075089233}}}
# #metrics {"StartTime": 1700106306.5671117, "EndTime": 1700106306.567132, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 4}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.633099638235074, "count": 1, "min": 1.633099638235074, "max": 1.633099638235074}}}
# #metrics {"StartTime": 1700106306.5671883, "EndTime": 1700106306.5672069, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 5}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6397269434822253, "count": 1, "min": 1.6397269434822253, "max": 1.6397269434822253}}}
# #metrics {"StartTime": 1700106306.5672617, "EndTime": 1700106306.5672798, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 6}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6323999155062836, "count": 1, "min": 1.6323999155062836, "max": 1.6323999155062836}}}
# #metrics {"StartTime": 1700106306.567347, "EndTime": 1700106306.5673647, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 7}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6100193791496107, "count": 1, "min": 1.6100193791496107, "max": 1.6100193791496107}}}
# #metrics {"StartTime": 1700106306.5674243, "EndTime": 1700106306.5674427, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 8}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6395865370290348, "count": 1, "min": 1.6395865370290348, "max": 1.6395865370290348}}}
# #metrics {"StartTime": 1700106306.567515, "EndTime": 1700106306.567533, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 9}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6303170542366587, "count": 1, "min": 1.6303170542366587, "max": 1.6303170542366587}}}
# #metrics {"StartTime": 1700106306.567588, "EndTime": 1700106306.5676064, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 10}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6421722070858502, "count": 1, "min": 1.6421722070858502, "max": 1.6421722070858502}}}
# #metrics {"StartTime": 1700106306.567659, "EndTime": 1700106306.567677, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 11}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6269988404295315, "count": 1, "min": 1.6269988404295315, "max": 1.6269988404295315}}}
# #metrics {"StartTime": 1700106306.5677273, "EndTime": 1700106306.5677452, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 12}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.628662292187968, "count": 1, "min": 1.628662292187968, "max": 1.628662292187968}}}
# #metrics {"StartTime": 1700106306.5678008, "EndTime": 1700106306.567819, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 13}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6181680661039992, "count": 1, "min": 1.6181680661039992, "max": 1.6181680661039992}}}
# #metrics {"StartTime": 1700106306.567871, "EndTime": 1700106306.5678885, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 14}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6055040755591834, "count": 1, "min": 1.6055040755591834, "max": 1.6055040755591834}}}
# #metrics {"StartTime": 1700106306.5679429, "EndTime": 1700106306.56796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 15}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.6085516591422475, "count": 1, "min": 1.6085516591422475, "max": 1.6085516591422475}}}
# #metrics {"StartTime": 1700106306.5680141, "EndTime": 1700106306.568032, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 16}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8057960473691312, "count": 1, "min": 1.8057960473691312, "max": 1.8057960473691312}}}
# #metrics {"StartTime": 1700106306.5681007, "EndTime": 1700106306.5681195, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 17}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.800145243684324, "count": 1, "min": 1.800145243684324, "max": 1.800145243684324}}}
# #metrics {"StartTime": 1700106306.5681782, "EndTime": 1700106306.5681965, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 18}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8049076433760671, "count": 1, "min": 1.8049076433760671, "max": 1.8049076433760671}}}
# #metrics {"StartTime": 1700106306.568249, "EndTime": 1700106306.5682662, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 19}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.7957435888223374, "count": 1, "min": 1.7957435888223374, "max": 1.7957435888223374}}}
# #metrics {"StartTime": 1700106306.5683234, "EndTime": 1700106306.5683422, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 20}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.786533014462017, "count": 1, "min": 1.786533014462017, "max": 1.786533014462017}}}
# #metrics {"StartTime": 1700106306.568396, "EndTime": 1700106306.568413, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 21}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.786712280858439, "count": 1, "min": 1.786712280858439, "max": 1.786712280858439}}}
# #metrics {"StartTime": 1700106306.5684817, "EndTime": 1700106306.5685012, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 22}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8044411229630248, "count": 1, "min": 1.8044411229630248, "max": 1.8044411229630248}}}
# #metrics {"StartTime": 1700106306.568568, "EndTime": 1700106306.5685883, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 23}, "Metrics": {"validation_absolute_loss_objective": {"sum": 1.8362116219517521, "count": 1, "min": 1.8362116219517521, "max": 1.8362116219517521}}}
# #metrics {"StartTime": 1700106306.5686574, "EndTime": 1700106306.5686774, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 24}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.3767861497287934, "count": 1, "min": 2.3767861497287934, "max": 2.3767861497287934}}}
# #metrics {"StartTime": 1700106306.5687385, "EndTime": 1700106306.5687575, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 25}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.3752159630528653, "count": 1, "min": 2.3752159630528653, "max": 2.3752159630528653}}}
# #metrics {"StartTime": 1700106306.5688145, "EndTime": 1700106306.5688324, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 26}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.3806916623831555, "count": 1, "min": 2.3806916623831555, "max": 2.3806916623831555}}}
# #metrics {"StartTime": 1700106306.5689003, "EndTime": 1700106306.5689187, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 27}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.367644922421001, "count": 1, "min": 2.367644922421001, "max": 2.367644922421001}}}
# #metrics {"StartTime": 1700106306.5689719, "EndTime": 1700106306.5689898, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 28}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.4260791315438266, "count": 1, "min": 2.4260791315438266, "max": 2.4260791315438266}}}
# #metrics {"StartTime": 1700106306.5690491, "EndTime": 1700106306.5690672, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 29}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.3229234409027586, "count": 1, "min": 2.3229234409027586, "max": 2.3229234409027586}}}
# #metrics {"StartTime": 1700106306.569127, "EndTime": 1700106306.5691452, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 30}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.3297550091728234, "count": 1, "min": 2.3297550091728234, "max": 2.3297550091728234}}}
# #metrics {"StartTime": 1700106306.5691984, "EndTime": 1700106306.5692165, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "model": 31}, "Metrics": {"validation_absolute_loss_objective": {"sum": 2.3626731470370066, "count": 1, "min": 2.3626731470370066, "max": 2.3626731470370066}}}
# [11/16/2023 03:45:06 INFO 140126792275776] #quality_metric: host=algo-1, epoch=12, validation absolute_loss_objective <loss>=1.6439013130748614
# [11/16/2023 03:45:06 INFO 140126792275776] #early_stopping_criteria_metric: host=algo-1, epoch=12, criteria=absolute_loss_objective, value=1.6055040755591834
# [11/16/2023 03:45:06 INFO 140126792275776] Saving model for epoch: 12
# [11/16/2023 03:45:06 INFO 140126792275776] Saved checkpoint to "/tmp/tmpl32im154/mx-mod-0000.params"
# [11/16/2023 03:45:06 INFO 140126792275776] Early stop condition met. Stopping training.
# [11/16/2023 03:45:06 INFO 140126792275776] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1700106305.695064, "EndTime": 1700106306.5759394, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 41022.0, "count": 1, "min": 41022, "max": 41022}, "Total Batches Seen": {"sum": 421.0, "count": 1, "min": 421, "max": 421}, "Max Records Seen Between Resets": {"sum": 2923.0, "count": 1, "min": 2923, "max": 2923}, "Max Batches Seen Between Resets": {"sum": 30.0, "count": 1, "min": 30, "max": 30}, "Reset Count": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Number of Records Since Last Reset": {"sum": 2923.0, "count": 1, "min": 2923, "max": 2923}, "Number of Batches Since Last Reset": {"sum": 30.0, "count": 1, "min": 30, "max": 30}}}
# [11/16/2023 03:45:06 INFO 140126792275776] #throughput_metric: host=algo-1, train throughput=3317.776504905918 records/second
# [11/16/2023 03:45:06 WARNING 140126792275776] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/16/2023 03:45:06 WARNING 140126792275776] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/16/2023 03:45:06 INFO 140126792275776] #early_stopping_criteria_metric: host=algo-1, epoch=12, criteria=absolute_loss_objective, value=1.6055040755591834
# [11/16/2023 03:45:06 INFO 140126792275776] #validation_score (algo-1) : ('absolute_loss_objective', 1.605543971442567)
# [11/16/2023 03:45:06 INFO 140126792275776] #validation_score (algo-1) : ('mse', 5.501833711569302)
# [11/16/2023 03:45:06 INFO 140126792275776] #validation_score (algo-1) : ('absolute_loss', 1.605543971442567)
# [11/16/2023 03:45:06 INFO 140126792275776] #validation_score (algo-1) : ('rmse', 2.3455987959515374)
# [11/16/2023 03:45:06 INFO 140126792275776] #validation_score (algo-1) : ('r2', 0.49797282669585874)
# [11/16/2023 03:45:06 INFO 140126792275776] #validation_score (algo-1) : ('mae', 1.605543986676981)
# [11/16/2023 03:45:06 INFO 140126792275776] #quality_metric: host=algo-1, validation absolute_loss_objective <loss>=1.605543971442567
# [11/16/2023 03:45:06 INFO 140126792275776] #quality_metric: host=algo-1, validation mse <loss>=5.501833711569302
# [11/16/2023 03:45:06 INFO 140126792275776] #quality_metric: host=algo-1, validation absolute_loss <loss>=1.605543971442567
# [11/16/2023 03:45:06 INFO 140126792275776] #quality_metric: host=algo-1, validation rmse <loss>=2.3455987959515374
# [11/16/2023 03:45:06 INFO 140126792275776] #quality_metric: host=algo-1, validation r2 <loss>=0.49797282669585874
# [11/16/2023 03:45:06 INFO 140126792275776] #quality_metric: host=algo-1, validation mae <loss>=1.605543986676981
# [11/16/2023 03:45:06 INFO 140126792275776] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.01, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [11/16/2023 03:45:06 INFO 140126792275776] Saved checkpoint to "/tmp/tmp8158dawf/mx-mod-0000.params"
# [11/16/2023 03:45:06 INFO 140126792275776] Test data is not provided.
# #metrics {"StartTime": 1700106293.715478, "EndTime": 1700106306.751224, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 466.70985221862793, "count": 1, "min": 466.70985221862793, "max": 466.70985221862793}, "epochs": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "check_early_stopping.time": {"sum": 5.720615386962891, "count": 14, "min": 0.1957416534423828, "max": 1.3813972473144531}, "update.time": {"sum": 12342.396974563599, "count": 13, "min": 827.3735046386719, "max": 1083.8210582733154}, "finalize.time": {"sum": 169.13700103759766, "count": 1, "min": 169.13700103759766, "max": 169.13700103759766}, "setuptime": {"sum": 2.8350353240966797, "count": 1, "min": 2.8350353240966797, "max": 2.8350353240966797}, "totaltime": {"sum": 13165.262222290039, "count": 1, "min": 13165.262222290039, "max": 13165.262222290039}}}
#
# 2023-11-16 03:45:22 Uploading - Uploading generated training model
# 2023-11-16 03:45:22 Completed - Training job completed
# Training seconds: 156
# Billable seconds: 156
# CPU times: user 600 ms, sys: 61.8 ms, total: 662 ms
# Wall time: 4min 44s

# %%
linear_model_uri = linear.model_data
print(linear_model_uri)
# Out:
# s3://sagemaker-us-east-1-220653215381/sagemaker/DEMO-linear-learner-abalone-regression/output/DEMO-linear-learner-abalone-regression-20231115-23-08-45/output/model.tar.gz

# %% [markdown]
# ### Configure the xgboost estimator

# %%
from sagemaker.xgboost.estimator import XGBoost

xgb_container = sagemaker.image_uris.retrieve("xgboost", sess.boto_region_name, "1.7-1")
display(xgb_container)
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1'

# %%
xgb_job_name = "xgboost-abalone-regression-" + strftime("%Y%m%d-%H-%M-%S", gmtime())
print("Training job", job_name)

xgb = sagemaker.estimator.Estimator(
    xgb_container,
    role,
    instance_count=1,
    instance_type="ml.m5.xlarge",
    output_path="s3://{}/{}/output".format(output_bucket, xgb_output_prefix),
    sagemaker_session=sess,
)
xgb.set_hyperparameters(
    max_depth=5,
    eta=0.2,
    gamma=4,
    min_child_weight=6,
    subsample=0.8,
    verbosity=0,
    objective="reg:squarederror",
    num_round=50,
)
# Out:
# Training job DEMO-linear-learner-abalone-regression-20231116-03-40-51

# %% [markdown]
# Train the XGBoost model

# %%
xgb.fit(inputs={"train": train_data, "validation": validation_data}, job_name=xgb_job_name)
# Out:
# INFO:sagemaker:Creating training-job with name: xgboost-abalone-regression-20231116-03-47-31
# 2023-11-16 03:47:38 Starting - Starting the training job...
# 2023-11-16 03:47:53 Starting - Preparing the instances for training......
# 2023-11-16 03:49:08 Downloading - Downloading input data......
# 2023-11-16 03:50:04 Training - Training image download completed. Training in progress...[2023-11-16 03:50:12.197 ip-10-2-107-168.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-11-16 03:50:12.231 ip-10-2-107-168.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2023-11-16:03:50:12:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-11-16:03:50:12:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2023-11-16:03:50:12:INFO] No GPUs detected (normal if no gpus installed)
# [2023-11-16:03:50:12:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-11-16:03:50:12:INFO] Determined 0 GPU(s) available on the instance.
# [2023-11-16:03:50:12:INFO] Determined delimiter of CSV input is ','
# [2023-11-16:03:50:12:INFO] Determined delimiter of CSV input is ','
# [2023-11-16:03:50:12:INFO] File path /opt/ml/input/data/train of input files
# [2023-11-16:03:50:12:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2023-11-16:03:50:12:INFO] creating symlink between Path /opt/ml/input/data/train/abalone_dataset1_train.csv and destination /tmp/sagemaker_xgboost_input_data/abalone_dataset1_train.csv-7838217578370847837
# [2023-11-16:03:50:12:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2023-11-16:03:50:12:INFO] Determined delimiter of CSV input is ','
# [2023-11-16:03:50:12:INFO] File path /opt/ml/input/data/validation of input files
# [2023-11-16:03:50:12:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2023-11-16:03:50:12:INFO] creating symlink between Path /opt/ml/input/data/validation/abalone_dataset1_validation.csv and destination /tmp/sagemaker_xgboost_input_data/abalone_dataset1_validation.csv-6924988041376049368
# [2023-11-16:03:50:12:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2023-11-16:03:50:12:INFO] Determined delimiter of CSV input is ','
# [2023-11-16:03:50:12:INFO] Single node training.
# [2023-11-16:03:50:12:INFO] Train matrix has 2923 rows and 8 columns
# [2023-11-16:03:50:12:INFO] Validation matrix has 626 rows
# [2023-11-16 03:50:12.669 ip-10-2-107-168.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-11-16 03:50:12.669 ip-10-2-107-168.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-11-16 03:50:12.670 ip-10-2-107-168.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2023-11-16 03:50:12.670 ip-10-2-107-168.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-11-16:03:50:12:INFO] Debug hook created from config
# [2023-11-16 03:50:12.676 ip-10-2-107-168.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2023-11-16 03:50:12.679 ip-10-2-107-168.ec2.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [0]#011train-rmse:8.08834#011validation-rmse:7.99333
# [1]#011train-rmse:6.60758#011validation-rmse:6.54626
# [2]#011train-rmse:5.44318#011validation-rmse:5.42483
# [3]#011train-rmse:4.53395#011validation-rmse:4.56638
# [4]#011train-rmse:3.84026#011validation-rmse:3.91107
# [5]#011train-rmse:3.30564#011validation-rmse:3.40621
# [6]#011train-rmse:2.91024#011validation-rmse:3.03974
# [7]#011train-rmse:2.61428#011validation-rmse:2.78353
# [8]#011train-rmse:2.39620#011validation-rmse:2.61691
# [9]#011train-rmse:2.24347#011validation-rmse:2.50548
# [10]#011train-rmse:2.13888#011validation-rmse:2.43259
# [11]#011train-rmse:2.06225#011validation-rmse:2.38231
# [12]#011train-rmse:1.99414#011validation-rmse:2.34910
# [13]#011train-rmse:1.95595#011validation-rmse:2.33116
# [14]#011train-rmse:1.91463#011validation-rmse:2.32167
# [15]#011train-rmse:1.88273#011validation-rmse:2.32067
# [16]#011train-rmse:1.85270#011validation-rmse:2.32468
# [17]#011train-rmse:1.83484#011validation-rmse:2.31333
# [18]#011train-rmse:1.82443#011validation-rmse:2.31085
# [19]#011train-rmse:1.81498#011validation-rmse:2.31171
# [20]#011train-rmse:1.80636#011validation-rmse:2.31158
# [21]#011train-rmse:1.78617#011validation-rmse:2.31152
# [22]#011train-rmse:1.78188#011validation-rmse:2.31294
# [23]#011train-rmse:1.76837#011validation-rmse:2.31218
# [24]#011train-rmse:1.76172#011validation-rmse:2.30948
# [25]#011train-rmse:1.75670#011validation-rmse:2.30842
# [26]#011train-rmse:1.75300#011validation-rmse:2.31005
# [27]#011train-rmse:1.75110#011validation-rmse:2.31020
# [28]#011train-rmse:1.74370#011validation-rmse:2.31228
# [29]#011train-rmse:1.74009#011validation-rmse:2.31515
# [30]#011train-rmse:1.73465#011validation-rmse:2.31619
# [31]#011train-rmse:1.73247#011validation-rmse:2.31670
# [32]#011train-rmse:1.72479#011validation-rmse:2.31423
# [33]#011train-rmse:1.71395#011validation-rmse:2.30986
# [34]#011train-rmse:1.70268#011validation-rmse:2.31427
# [35]#011train-rmse:1.69727#011validation-rmse:2.31476
# [36]#011train-rmse:1.69181#011validation-rmse:2.31693
# [37]#011train-rmse:1.68853#011validation-rmse:2.31611
# [38]#011train-rmse:1.68076#011validation-rmse:2.32480
# [39]#011train-rmse:1.66956#011validation-rmse:2.32654
# [40]#011train-rmse:1.66336#011validation-rmse:2.32485
# [41]#011train-rmse:1.66037#011validation-rmse:2.32472
# [42]#011train-rmse:1.65045#011validation-rmse:2.32297
# [43]#011train-rmse:1.63924#011validation-rmse:2.32755
# [44]#011train-rmse:1.63250#011validation-rmse:2.32797
# [45]#011train-rmse:1.62929#011validation-rmse:2.33171
# [46]#011train-rmse:1.62755#011validation-rmse:2.33200
# [47]#011train-rmse:1.61613#011validation-rmse:2.33773
# [48]#011train-rmse:1.61013#011validation-rmse:2.34205
# [49]#011train-rmse:1.60759#011validation-rmse:2.33990
#
# 2023-11-16 03:50:31 Uploading - Uploading generated training model
# 2023-11-16 03:50:31 Completed - Training job completed
# Training seconds: 83
# Billable seconds: 83

# %%
xgb_model_uri = xgb.model_data
print(xgb_model_uri)
# Out:
# s3://sagemaker-us-east-1-220653215381/sagemaker/DEMO-xgb-abalone-regression/output/xgboost-abalone-regression-20231116-03-47-31/output/model.tar.gz

# %% [markdown]
# ### Training with automatic model tuning (HPO)

# %%
import time
from sagemaker.tuner import IntegerParameter, ContinuousParameter
from sagemaker.tuner import HyperparameterTuner

job_name = "DEMO-ll-aba-" + time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())
print("Tuning job name: ", job_name)

# Linear Learner tunable hyper parameters can be found here https://docs.aws.amazon.com/sagemaker/latest/dg/linear-learner-tuning.html
hyperparameter_ranges = {
    "wd": ContinuousParameter(1e-7, 1, scaling_type="Auto"),
    "learning_rate": ContinuousParameter(1e-5, 1, scaling_type="Auto"),
    "mini_batch_size": IntegerParameter(100, 2000, scaling_type="Auto"),
}

# Increase the total number of training jobs run by AMT, for increased accuracy (and training time).
max_jobs = 6
# Change parallel training jobs run by AMT to reduce total training time, constrained by your account limits.
# if max_jobs=max_parallel_jobs then Bayesian search turns to Random.
max_parallel_jobs = 2


hp_tuner = HyperparameterTuner(
    linear,
    "validation:mse",
    hyperparameter_ranges,
    max_jobs=max_jobs,
    max_parallel_jobs=max_parallel_jobs,
    objective_type="Minimize",
)


# Launch a SageMaker Tuning job to search for the best hyperparameters
hp_tuner.fit(inputs={"train": train_data, "validation": validation_data}, job_name=job_name)
# Out:
# INFO:sagemaker:Creating hyperparameter tuning job with name: DEMO-ll-aba-2023-11-15-23-16-47
# Tuning job name:  DEMO-ll-aba-2023-11-15-23-16-47
# ...................................................................................!

# %% [markdown]
# # Deploy model

# %% [markdown]
# ### Create model definition

# %%
model_name = f"xgb-abalone-{datetime.now():%Y-%m-%d-%H-%M-%S}"
print(model_name)

##sess.create_model(name=model_name, container_defs={"Image": xgb_container, "ModelDataUrl": xgb_model_uri})
create_model_response = sm_client.create_model(ModelName = model_name,ExecutionRoleArn = role,PrimaryContainer = {'Image': xgb_container,'ModelDataUrl': xgb_model_uri})
# Out:
# xgb-abalone-2023-11-16-03-52-54

# %% [markdown]
# ### Create endpoint

# %%
from sagemaker.session import production_variant

# Create an endpoint with the 2 production variants
endpoint_name = f"xgb-Abalone-{datetime.now():%Y-%m-%d-%H-%M-%S}"
 
xgbvariant = production_variant(
	model_name=model_name,
	instance_type="ml.c5.xlarge",
	initial_instance_count=1,
	variant_name="xgb-variant",
	initial_weight=1
	)

endpoint_response = sess.endpoint_from_production_variants(
	name=endpoint_name,
	production_variants=[xgbvariant]
	)
# Out:
# INFO:sagemaker:Creating endpoint-config with name xgb-Abalone-2023-11-16-03-54-28
# INFO:sagemaker:Creating endpoint with name xgb-Abalone-2023-11-16-03-54-28
# ----!

# %%
## Check the status of the endpoint of update 
print ("The current status of the endpoint is: {}".format(sm_client.describe_endpoint(EndpointName = endpoint_name)["EndpointStatus"]))
# Out:
# The current status of the endpoint is: InService

# %% [markdown]
# ### Test the endpoint

# %%
#### Prepare data for inference

# %%
import pandas as pd
df = pd.read_csv(f"{FILE_TRAIN}")
df2 = df.iloc[:, 1:]

df2.to_csv('abalone_inference_data.csv', index=False)

# %%
sm_runtime = boto3.Session().client("sagemaker-runtime")
#send-test-data
print(f"Sending test traffic to the endpoint {endpoint_name}. \nPlease wait...")

error_count = 0
for i in range(0,1):
    with open("abalone_inference_data.csv", "r") as f:
        for row in f:
            print(".", end="", flush=True)
            payload = row.rstrip("\n")
            try:
                response = sm_runtime.invoke_endpoint(
                    EndpointName=endpoint_name, ContentType="text/csv", Body=payload
                )
                response["Body"].read()
                print(".", end="", flush=True)
            except Exception as e:
                print("E", end="", flush=True)
                error_count += 1
                if error_count >= 5:
                    break
            time.sleep(0.1)
f.close()
print("Done!")
# Out:
# Sending test traffic to the endpoint xgb-Abalone-2023-11-16-03-54-28.
# Please wait...
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...

# %% [markdown]
# # Create Archive of Sample Workload
# We need to create an archive that contains individual files that Inference Recommender can send to your SageMaker Endpoints. Inference Recommender will randomly sample files from this archive so make sure it contains a similar distribution of payloads you'd expect in production. Note that your inference code must be able to read in the file formats from the sample payload.
#
# Here we are only adding a single CSV file for the example. In your own use case(s), it's recommended to add a variety of samples that is representative of your payloads.

# %%
from sagemaker.s3 import S3Downloader, S3Uploader
# tar inference data and upload to S3, which we will use for the payload for the inference recommender
# !tar -czvf ./abalone_inference_data.tar.gz ./abalone_inference_data.csv
inference_prefix = 'inference-data'
# Upload models
inference_data_uri = S3Uploader.upload(local_path="abalone_inference_data.tar.gz", desired_s3_uri=f"s3://{output_bucket}/{xgb_output_prefix}/{inference_prefix}")
print(inference_data_uri)
# Out:
# ./abalone_inference_data.csv
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml
# s3://sagemaker-us-east-1-220653215381/sagemaker/DEMO-xgb-abalone-regression/inference-data/abalone_inference_data.tar.gz

# %% [markdown]
# # Inference recommender

# %% [markdown]
# ## Default inference recommender jobs

# %% [markdown]
# ### Configure parameters for default inference recommender jobs
# Inference Recommender uses metadata about your ML model to recommend the best instance types and endpoint configurations for deployment. You can provide as much or as little information as you'd like but the more information you provide, the better your recommendations will be.

# %%
list_model_metadata_response=sm_client.list_model_metadata()
for model_metadata in list_model_metadata_response['ModelMetadataSummaries']:
    if model_metadata['Framework'] == 'XGBOOST':
        print(model_metadata)
# Out:
# {'Domain': 'MACHINE_LEARNING', 'Framework': 'XGBOOST', 'Task': 'CLASSIFICATION', 'Model': 'xgboost', 'FrameworkVersion': '1.0-1'}
# {'Domain': 'MACHINE_LEARNING', 'Framework': 'XGBOOST', 'Task': 'REGRESSION', 'Model': 'xgboost', 'FrameworkVersion': '1.3-1'}

# %%
## Uncomment if you did not store the domain and task in a previous step
ml_domain = 'MACHINE_LEARNING'
ml_task = 'REGRESSION'

## Uncomment if you did not store the framework and framework version in a previous step
framework = 'XGBOOST'
framework_version = '1.0-1'

# The name of the ML model as standardized by common model zoos
nearest_model_name = 'xgboost'

# The supported MIME types for input and output data. In this example, 
# we are using images as input
input_content_type='text/csv'

# %%
# Create a dictionary to use as input for creating an inference recommendation job
container_config = {
        "Domain": ml_domain,
        "Framework": framework, 
        "FrameworkVersion": framework_version,
        "NearestModelName": nearest_model_name,
        "PayloadConfig": { 
            "SamplePayloadUrl": inference_data_uri,
            "SupportedContentTypes": [ input_content_type ]
         },
        "Task": ml_task,
        }

# %% [markdown]
# ### Create default inference recommender jobs
# Inference recommendations (Default job type) run a set of load tests on the recommended instance types. You can also load test for a serverless endpoint..

# %%
## We'll using inference recommender for one of the producttion variants
recommender_model_name = model_name

# Provide a unique job name for SageMaker Inference Recommender job
job_name = f'abalone-recommender-job-name-{datetime.now():%Y-%m-%d-%H-%M-%S}'

# Inference Recommender job type. Set to Default to get an initial recommendation
job_type = 'Default'

sm_client.create_inference_recommendations_job(
    JobName = job_name,
    JobType = job_type,
    RoleArn = role,
    # Provide only one of model package ARN or model name, not both. 
    # If you would like to create an inference recommendations job with a model name,
    # uncomment ModelName and ContainerConfig, and comment out ModelPackageVersionArn.
    InputConfig = {
        'ModelName': recommender_model_name,
        'ContainerConfig': container_config
        
    }
    
)
# Out:
# {'JobArn': 'arn:aws:sagemaker:us-east-1:220653215381:inference-recommendations-job/abalone-recommender-job-name-2023-11-16-04-08-25',
#  'ResponseMetadata': {'RequestId': 'ae416f2a-08e6-42b3-8e24-4202f9c97611',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'ae416f2a-08e6-42b3-8e24-4202f9c97611',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '132',
#    'date': 'Thu, 16 Nov 2023 04:08:26 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Advanced Inference recommender job
# Endpoint recommendations (Advanced job type) are based on a custom load test where you select your desired ML instances or a serverless endpoint, provide a custom traffic pattern, and provide requirements for latency and throughput based on your production requirements. This job takes an average of 2 hours to complete depending on the job duration set and the total number of inference configurations tested.

# %% [markdown]
# ### Configure advanced recommender job
# Configure and run an advanced Inference Recommender job to perform a custom load test to simulate user interactions with the application. This helps you find the right configurations to satisfy latency, concurrency, and cost for this use case.

# %%
from sagemaker.parameter import CategoricalParameter 
from sagemaker.inference_recommender.inference_recommender_mixin import (  
    Phase,  
    ModelLatencyThreshold 
) 

hyperparameter_ranges = [ 
    { 
        "instance_types": CategoricalParameter(["ml.m5.2xlarge", "ml.m5.4xlarge", "ml.g4dn.xlarge"]), 
        'OMP_NUM_THREADS': CategoricalParameter(['3','4','5']), 
    } 
] 

phases = [ 
    Phase(duration_in_seconds=120, initial_number_of_users=2, spawn_rate=2),
] 

model_latency_thresholds = [ 
    ModelLatencyThreshold(percentile="P95", value_in_milliseconds=100) 
]

# %%
from sagemaker.model import Model
from sagemaker import image_uris
import sagemaker

model = Model(
    model_data=xgb_model_uri,
    role=role,
    image_uri = sagemaker.image_uris.retrieve(framework="xgboost", region=region, version="1.7-1", py_version="py3", 
                                              image_scope='inference'),
    sagemaker_session=sess
    )
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary Python version: py3.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.

# %% [markdown]
# ## Run the recommender job
# We recently released Python SDK support for Inference Recommender. You can now run default and advanced jobs using a single function: [right_size](https://sagemaker.readthedocs.io/en/stable/api/inference/model.html#sagemaker.model.Model.right_size). Based on the parameters of the function call, Inference Recommender infers if it should run default or advanced jobs. This greatly simplifies the use of Inference Recommender using the Python SDK. To run the Inference Recommender job, complete the following steps

# %%
advanced_job_name=f"advanced-abalone-recommender-job-{str(round(time.time()))}"

model.right_size( 
    sample_payload_url=inference_data_uri, 
    supported_content_types=["text/csv"], 
    framework= framework, 
    job_duration_in_seconds=7200, 
    hyperparameter_ranges=hyperparameter_ranges, 
    phases=phases, # TrafficPattern 
    max_invocations=30000, # StoppingConditions 
    model_latency_thresholds=model_latency_thresholds,
    job_name=advanced_job_name
)
# Out:
# INFO:sagemaker:Advanced Job parameters were specified. Running Advanced job...
# WARNING:sagemaker:Attempting to create new model with name sagemaker-xgboost-2023-11-16-04-09-11-338
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2023-11-16-04-09-11-338
# INFO:sagemaker:Creating Inference Recommendations job with name: advanced-abalone-recommender-job-1700107751
# Fetching logs from CloudWatch...
# Retrieved logStream: advanced-abalone-recommender-job-1700107751/execution from logGroup: /aws/sagemaker/InferenceRecommendationsJobs
# [INFO] Starting Inference Recommendations Job advanced-abalone-recommender-job-1700107751
# [INFO] Job type is LOAD_TEST
# [INFO] Model name provided; retrieving model details from model: sagemaker-xgboost-2023-11-16-04-09-11-338
# [INFO] Validating existence of sample payload
# [INFO] Successfully validated existence of sample payload. Validating size of sample payload
# [INFO] Successfully validated size of sample payload.
# [INFO] Successfully retrieved model details.
# [INFO] Validating job inputs
# [INFO] Image url is: 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1
# [INFO] Image type is: ALGORITHM
# [INFO] SupportedRealtimeInferenceInstanceTypes not provided, using default list.
# [INFO] Provided SupportedRealtimeInferenceInstanceTypes are: [ml.c4.2xlarge, ml.c4.4xlarge, ml.c4.8xlarge, ml.c4.large, ml.c4.xlarge, ml.c5.18xlarge, ml.c5.2xlarge, ml.c5.4xlarge, ml.c5.9xlarge, ml.c5.large, ml.c5.xlarge, ml.c5d.18xlarge, ml.c5d.2xlarge, ml.c5d.4xlarge, ml.c5d.9xlarge, ml.c5d.large, ml.c5d.xlarge, ml.eia1.large, ml.eia1.medium, ml.eia1.xlarge, ml.eia2.large, ml.eia2.medium, ml.eia2.xlarge, ml.g4dn.12xlarge, ml.g4dn.16xlarge, ml.g4dn.2xlarge, ml.g4dn.4xlarge, ml.g4dn.8xlarge, ml.g4dn.xlarge, ml.g5.12xlarge, ml.g5.16xlarge, ml.g5.24xlarge, ml.g5.2xlarge, ml.g5.48xlarge, ml.g5.4xlarge, ml.g5.8xlarge, ml.g5.xlarge, ml.m4.10xlarge, ml.m4.16xlarge, ml.m4.2xlarge, ml.m4.4xlarge, ml.m4.xlarge, ml.m5.12xlarge, ml.m5.24xlarge, ml.m5.2xlarge, ml.m5.4xlarge, ml.m5.large, ml.m5.xlarge, ml.m5d.12xlarge, ml.m5d.24xlarge, ml.m5d.2xlarge, ml.m5d.4xlarge, ml.m5d.large, ml.m5d.xlarge, ml.p2.16xlarge, ml.p2.8xlarge, ml.p2.xlarge, ml.p3.16xlarge, ml.p3.2xlarge, ml.p3.8xlarge, ml.p5.48xlarge, ml.r5.12xlarge, ml.r5.24xlarge, ml.r5.2xlarge, ml.r5.4xlarge, ml.r5.large, ml.r5.xlarge, ml.r5d.12xlarge, ml.r5d.24xlarge, ml.r5d.2xlarge, ml.r5d.4xlarge, ml.r5d.large, ml.r5d.xlarge, ml.t2.2xlarge, ml.t2.large, ml.t2.medium, ml.t2.xlarge]
# [INFO] Filtering for instance types that are available in region and compatible with image
# [INFO] Filtered instance types list is: [ml.c4.2xlarge, ml.c4.4xlarge, ml.c4.8xlarge, ml.c4.large, ml.c4.xlarge, ml.c5.18xlarge, ml.c5.2xlarge, ml.c5.4xlarge, ml.c5.9xlarge, ml.c5.large, ml.c5.xlarge, ml.c5d.18xlarge, ml.c5d.2xlarge, ml.c5d.4xlarge, ml.c5d.9xlarge, ml.c5d.large, ml.c5d.xlarge, ml.g4dn.12xlarge, ml.g4dn.16xlarge, ml.g4dn.2xlarge, ml.g4dn.4xlarge, ml.g4dn.8xlarge, ml.g4dn.xlarge, ml.g5.12xlarge, ml.g5.16xlarge, ml.g5.24xlarge, ml.g5.2xlarge, ml.g5.48xlarge, ml.g5.4xlarge, ml.g5.8xlarge, ml.g5.xlarge, ml.m4.10xlarge, ml.m4.16xlarge, ml.m4.2xlarge, ml.m4.4xlarge, ml.m4.xlarge, ml.m5.12xlarge, ml.m5.24xlarge, ml.m5.2xlarge, ml.m5.4xlarge, ml.m5.large, ml.m5.xlarge, ml.m5d.12xlarge, ml.m5d.24xlarge, ml.m5d.2xlarge, ml.m5d.4xlarge, ml.m5d.large, ml.m5d.xlarge, ml.p2.16xlarge, ml.p2.8xlarge, ml.p2.xlarge, ml.p3.16xlarge, ml.p3.2xlarge, ml.p3.8xlarge, ml.p5.48xlarge, ml.r5.12xlarge, ml.r5.24xlarge, ml.r5.2xlarge, ml.r5.4xlarge, ml.r5.large, ml.r5.xlarge, ml.r5d.12xlarge, ml.r5d.24xlarge, ml.r5d.2xlarge, ml.r5d.4xlarge, ml.r5d.large, ml.r5d.xlarge]
# [INFO] Determining if requirements are met to try model compilation
# [INFO] Skipping model compilation because job type is LOAD_TEST.
# [INFO] Scheduling benchmark job with configuration: {InstanceType: ml.m5.2xlarge, InitialInstanceCount: 1, Environment: {OMP_NUM_THREADS=3}, Image: 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1}
# [INFO] Please check the logs in /aws/sagemaker/InferenceRecommendationsJobs/advanced-abalone-recommender-job-1700107751/Endpoint/ for details
# [INFO] Number of completed benchmark jobs: 0, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 0, number of pending benchmark jobs: 1.
# [INFO] Current job running duration: 89 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 0, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 150 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 0, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 211 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 0, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 272 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 0, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 333 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 0, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 394 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 0, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 454 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 0, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 515 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 0, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 576 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 0, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 636 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 0, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 697 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 0, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 758 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 0, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 818 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 1, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 0, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 879 seconds, maximum job duration: 7200 seconds
# [INFO] Scheduling benchmark job with configuration: {InstanceType: ml.m5.2xlarge, InitialInstanceCount: 1, Environment: {OMP_NUM_THREADS=4}, Image: 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1}
# [INFO] Please check the logs in /aws/sagemaker/InferenceRecommendationsJobs/advanced-abalone-recommender-job-1700107751/Endpoint/ for details
# [INFO] Number of completed benchmark jobs: 1, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 0, number of pending benchmark jobs: 1.
# [INFO] Current job running duration: 883 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 1, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 943 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 1, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1004 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 1, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1065 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 1, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1125 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 1, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1186 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 1, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1247 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 1, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1308 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 1, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1369 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 1, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1429 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 2, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 0, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1490 seconds, maximum job duration: 7200 seconds
# [INFO] Scheduling benchmark job with configuration: {InstanceType: ml.m5.2xlarge, InitialInstanceCount: 1, Environment: {OMP_NUM_THREADS=5}, Image: 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1}
# [INFO] Please check the logs in /aws/sagemaker/InferenceRecommendationsJobs/advanced-abalone-recommender-job-1700107751/Endpoint/ for details
# [INFO] Number of completed benchmark jobs: 2, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 0, number of pending benchmark jobs: 1.
# [INFO] Current job running duration: 1509 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 2, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1570 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 2, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1630 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 2, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1691 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 2, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1752 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 2, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1813 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 2, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1873 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 2, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1934 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 2, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 1995 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 2, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2056 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 2, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2116 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 2, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2177 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 2, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2238 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 3, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 0, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2298 seconds, maximum job duration: 7200 seconds
# [INFO] Scheduling benchmark job with configuration: {InstanceType: ml.m5.4xlarge, InitialInstanceCount: 1, Environment: {OMP_NUM_THREADS=3}, Image: 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1}
# [INFO] Please check the logs in /aws/sagemaker/InferenceRecommendationsJobs/advanced-abalone-recommender-job-1700107751/Endpoint/ for details
# [INFO] Number of completed benchmark jobs: 3, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 0, number of pending benchmark jobs: 1.
# [INFO] Current job running duration: 2318 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 3, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2379 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 3, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2439 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 3, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2500 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 3, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2561 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 3, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2621 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 3, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2682 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 3, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2743 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 3, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2803 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 3, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2864 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 3, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2925 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 3, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 2985 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 3, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3046 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 4, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 0, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3107 seconds, maximum job duration: 7200 seconds
# [INFO] Scheduling benchmark job with configuration: {InstanceType: ml.m5.4xlarge, InitialInstanceCount: 1, Environment: {OMP_NUM_THREADS=4}, Image: 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1}
# [INFO] Please check the logs in /aws/sagemaker/InferenceRecommendationsJobs/advanced-abalone-recommender-job-1700107751/Endpoint/ for details
# [INFO] Number of completed benchmark jobs: 4, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 0, number of pending benchmark jobs: 1.
# [INFO] Current job running duration: 3126 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 4, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3186 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 4, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3247 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 4, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3308 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 4, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3369 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 4, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3429 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 4, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3490 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 4, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3551 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 4, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3612 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 4, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3672 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 4, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3733 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 4, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3794 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 4, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 1, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3861 seconds, maximum job duration: 7200 seconds
# [INFO] Number of completed benchmark jobs: 5, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 0, number of pending benchmark jobs: 0.
# [INFO] Current job running duration: 3923 seconds, maximum job duration: 7200 seconds
# [INFO] Scheduling benchmark job with configuration: {InstanceType: ml.m5.4xlarge, InitialInstanceCount: 1, Environment: {OMP_NUM_THREADS=5}, Image: 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1}
# [INFO] Please check the logs in /aws/sagemaker/InferenceRecommendationsJobs/advanced-abalone-recommender-job-1700107751/Endpoint/ for details
# [INFO] Number of completed benchmark jobs: 5, number of failed benchmark jobs: 0, number of in progress benchmark jobs: 0, number of pending benchmark jobs: 1.
# [INFO] Current job running duration: 3943 seconds, maximum job duration: 7200 seconds

# %% [markdown]
# ### Check the status of the inference recommendation job

# %%
## Check the status of the inference recommendation
import pprint
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

finished = False
while not finished:
    inference_recommender_job = sm_client.describe_inference_recommendations_job(
        JobName=job_name
    )
    if inference_recommender_job["Status"] in ["COMPLETED", "STOPPED", "FAILED"]:
        finished = True
    else:
        print("In progress")
        time.sleep(300)

if inference_recommender_job["Status"] == "FAILED":
    print("Inference recommender job failed ")
    print("Failed Reason: {}".format(inference_recommender_job["FailureReason"]))
else:
    print("Inference recommender job completed")
# Out:
# Inference recommender job completed

# %% [markdown]
# ### View inference recommender job output

# %%
data = [
    {**x["EndpointConfiguration"], **x["ModelConfiguration"], **x["Metrics"]}
    for x in inference_recommender_job["InferenceRecommendations"]
]
df = pd.DataFrame(data)
dropFilter = df.filter(["VariantName"])
df.drop(dropFilter, inplace=True, axis=1)
pd.set_option("max_colwidth", 400)
df.head()
# Out:
#                                                     EndpointName    InstanceType  InitialInstanceCount                                                                                                                              EnvironmentParameters  CostPerHour  CostPerInference  MaxInvocations  ModelLatency  CpuUtilization  MemoryUtilization                               ServerlessConfig CompilationJobName
# 0  abalone-recommender-job-name-2023-11-16--WiVRAaKECJ7NzaVqegdR     ml.c5.large                   1.0  [{'Key': 'SAGEMAKER_MODEL_SERVER_WORKERS', 'ValueType': 'String', 'Value': '2'}, {'Key': 'OMP_NUM_THREADS', 'ValueType': 'String', 'Value': '1'}]        0.102      6.561173e-07            2591           208      182.044006          10.123600                                            NaN                NaN
# 1  abalone-recommender-job-name-2023-11-16--dDaCsnrT1JJMql88OXcG  ml.g4dn.xlarge                   1.0  [{'Key': 'SAGEMAKER_MODEL_SERVER_WORKERS', 'ValueType': 'String', 'Value': '1'}, {'Key': 'OMP_NUM_THREADS', 'ValueType': 'String', 'Value': '1'}]        0.736      5.629493e-06            2179            96      102.608002           1.572550                                            NaN                NaN
# 2  abalone-recommender-job-name-2023-11-16--wZGBSldNeoWODfXaKN42    ml.c5.xlarge                   1.0  [{'Key': 'SAGEMAKER_MODEL_SERVER_WORKERS', 'ValueType': 'String', 'Value': '4'}, {'Key': 'OMP_NUM_THREADS', 'ValueType': 'String', 'Value': '1'}]        0.204      6.874242e-07            4946           143      361.787994           7.499210                                            NaN                NaN
# 3  abalone-recommender-job-name-2023-11-16--ZMe9xifzimxvk4R7tjNy             NaN                   NaN                                                                                                                                                 []        0.360      9.615384e-06             624            35             NaN           8.650984  {'MemorySizeInMB': 5120, 'MaxConcurrency': 1}                NaN
# 4  abalone-recommender-job-name-2023-11-16--ke5M16q1pXNPEYeVPlA3   ml.c5.2xlarge                   1.0  [{'Key': 'SAGEMAKER_MODEL_SERVER_WORKERS', 'ValueType': 'String', 'Value': '8'}, {'Key': 'OMP_NUM_THREADS', 'ValueType': 'String', 'Value': '1'}]        0.408      6.535948e-07           10404           155      708.270996           6.515830                                            NaN                NaN

# %% [markdown]
# ## Cleanup

# %%
sm_client.delete_endpoint(EndpointName=endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': 'd875cf62-5320-4c23-ac3e-3d96bc19a2c7',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'd875cf62-5320-4c23-ac3e-3d96bc19a2c7',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Wed, 08 Nov 2023 19:30:51 GMT'},
#   'RetryAttempts': 0}}
